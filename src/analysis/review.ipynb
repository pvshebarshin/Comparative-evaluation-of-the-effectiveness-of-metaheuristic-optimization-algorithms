# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
import math

from pylab import rcParams
from ipywidgets import interactive
from matplotlib import cm  # color ma
from mpl_toolkits.mplot3d import Axes3D
from numpy import exp, sin, cos, pi, sqrt, fabs
from functions import *

# %matplotlib inline

# %%
dataset = pd.read_csv('result.csv')
dataset
# Out:
#       Name_Evr                                    Name_Fun      Time  Epoch  \
# 0          IWO                              easom_function  0.042803     10
# 1          IWO                             ackley_function  0.036030     10
# 2          IWO                           ackley_function_3  0.033639     10
# 3          IWO                              keane_function  0.032179     10
# 4          IWO                        michaelwicz_function  0.030721     10
# ...        ...                                         ...       ...    ...
# 66393      ACO  composite_xin_she_yang_4_schwefel_function  1.876112   1000
# 66394      ACO  composite_cross_in_tray_drop_wave_function  1.794891   1000
# 66395      ACO       composite_schaffer_drop_wave_function  1.766238   1000
# 66396      ACO                  composite_shubert_function  1.965574   1000
# 66397      ACO       composite_shubert_4_levin_function_13  1.903097   1000
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66398 entries, 0 to 66397
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name_Evr    66398 non-null  object
#  1   Name_Fun    66398 non-null  object
#  2   Time        66398 non-null  float64
#  3   Epoch       66398 non-null  int64
#  4   Best_Fit    66398 non-null  float64
#  5   Std         66398 non-null  float64
#  6   Optimum     66398 non-null  float64
#  7   Parameters  66398 non-null  object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
x1 = np.linspace(-100, 100)
x2 = np.linspace(-100, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, easom_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, easom_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Easom Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-60, 120, 5), A = (-60, 20, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=120, min=-60, step=5), IntSlider(value=-20, des…

# %%
x1 = np.arange(-32.768, 32.768, 2.0)
x2 = np.arange(-32.768, 32.768, 2.0)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, ackley_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, ackley_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x2', fontsize=10)
    ax.set_ylabel('x1', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Ackley Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-32, 32)
x2 = np.linspace(-32, 32)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, ackley_function_3([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, ackley_function_3([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Ackley Function №3')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(10, -10)
x2 = np.linspace(10, -10)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, keane_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, keane_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Keane Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(0, 3.2, 50)    
x2 = np.linspace(0, 3.2, 50)    
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, michaelwicz_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, michaelwicz_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Michaelwicz Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-5, 10)
x2 = np.linspace(-5, 10)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, rosenbrook_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, rosenbrook_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('z2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Rosenbrook Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(0, 3)
x2 = np.linspace(0, 3)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, nonsmooth_multipeak_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, nonsmooth_multipeak_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Nonsmooth Multipeak Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(4, -4) 
x2 = np.linspace(4, -4) 
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, brown_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, brown_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Brown Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10)
x2 = np.linspace(-10, 10)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, levin_function_13([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, levin_function_13([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x2', fontsize=10)
    ax.set_ylabel('x1', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Levi Function №13')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-2 * pi, 2 * pi, 100)
x2 = np.linspace(-2 * pi, 2 * pi, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, bird_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, bird_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Bird Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-500, 500)
x2 = np.linspace(-500, 500)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, schwefel_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, schwefel_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Schwefel Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-20, 0, 20)
x2 = np.linspace(-20, 0, 20)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, brent_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, brent_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Brent Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-20, 20, 100)
x2 = np.linspace(-20, 20, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, deckkers_aarts_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, deckkers_aarts_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Deckkers Aarts Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

# plotter(45,45)
iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10, 30)
x2 = np.linspace(-10, 10, 30)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, xin_she_yang_function_4([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, xin_she_yang_function_4([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x', fontsize=10)
    ax.set_ylabel('y', fontsize=10)
    ax.set_zlabel('f(x,y)', fontsize=10)
    ax.set_title('Xin She Yang Function №4')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-512, 512, 100)
x2 = np.linspace(-512, 512, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, eggholder_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, eggholder_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Eggholder Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10, 100)
x2 = np.linspace(-10, 10, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, shubert_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, shubert_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Shubert Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-50, 50)
x2 = np.linspace(-50, 50)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, schaffer_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, schaffer_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Schaffer Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10, 20)
x2 = np.linspace(-10, 10, 20)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, shubert_function_4([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, shubert_function_4([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Shubert Function №4')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-5.12, 5.12, 100)
x2 = np.linspace(-5.12, 5.12, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, drop_wave_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, drop_wave_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Drop Wave Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10, 100)
x2 = np.linspace(-10, 10, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, cross_in_tray_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, cross_in_tray_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Cross In Tray Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10, 30)
x2 = np.linspace(-10, 10, 30)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, composite_xin_she_yang_4_schwefel_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, composite_xin_she_yang_4_schwefel_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Composite Xin She Yang №4 and Schwefel Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-5.12, 5.12, 100)
x2 = np.linspace(-5.12, 5.12, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, composite_cross_in_tray_drop_wave_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, composite_cross_in_tray_drop_wave_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Composite Cross In Tray And Drop Wave Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-5.12, 5.12, 100)
x2 = np.linspace(-5.12, 5.12, 100)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, composite_schaffer_drop_wave_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, composite_schaffer_drop_wave_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Composite Schaffer Drop Wave Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10, 20)
x2 = np.linspace(-10, 10, 20)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, composite_shubert_function([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, composite_shubert_function([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Composite Shibert Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…

# %%
x1 = np.linspace(-10, 10, 30)
x2 = np.linspace(-10, 10, 30)
X1, X2 = np.meshgrid(x1, x2)
plt.contour(X1, X2, composite_shubert_4_levin_function_13([X1, X2]))

# %%
def plotter(E, A):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    surf = ax.plot_surface(X1, X2, composite_shubert_4_levin_function_13([X1, X2]), \
        rstride=1, cstride=1, cmap=cm.jet, \
        edgecolor='darkred', linewidth=0.1)

    ax.set_xlabel('x1', fontsize=10)
    ax.set_ylabel('x2', fontsize=10)
    ax.set_zlabel('f(x1, x2)', fontsize=10)
    ax.set_title('Composite Shubert №4 and Levi №13 Function')
    ax.tick_params(axis='both', which='major', labelsize=6)
    ax.view_init(elev=E, azim=A)

iplot = interactive(plotter, E = (-30, 90, 5), A = (-30, 90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=30, description='E', max=90, min=-30, step=5), IntSlider(value=30, descr…
